# %%
import jwt 

import warnings

# %%
encoded_jwt = jwt.encode({"some": "payload"}, "secret", algorithm="HS256")

encoded_jwt
# Out:
# /Users/blaiseforgwa/projects/learning-fastapi/.venv/lib/python3.13/site-packages/jwt/api_jwt.py:153: InsecureKeyLengthWarning: The HMAC key is 6 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzb21lIjoicGF5bG9hZCJ9.4twFt5NiznN84AWoo1d7KO1T_yoc0Z6XOpOVswacPZg'

# %%
jwt.decode(encoded_jwt, "secret", algorithms=["HS256"])
# Out:
# /Users/blaiseforgwa/projects/learning-fastapi/.venv/lib/python3.13/site-packages/jwt/api_jwt.py:371: InsecureKeyLengthWarning: The HMAC key is 6 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   decoded = self.decode_complete(
# {'some': 'payload'}

# %%
from authentication import AuthHandler

auth = AuthHandler()

# Fake user
user_id = "507f1f77bcf86cd799439011"
username = "blaise"

token = auth.encode_token(user_id, username)
print("TOKEN:", token)

decoded = auth.decode_token(token)
print("DECODED:", decoded)

assert decoded["user_id"] == user_id
assert decoded["username"] == username

print("✅ AuthHandler works correctly")
# Out:
# TOKEN: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NzA1NTA3NDQsImlhdCI6MTc3MDU0ODk0NCwic3ViIjoiNTA3ZjFmNzdiY2Y4NmNkNzk5NDM5MDExIiwidXNlcm5hbWUiOiJibGFpc2UifQ.KJc1Z3E1GNMwYYy-Z3Czh57ljJuR4tGCymHYHpwaS0w
# DECODED: {'user_id': '507f1f77bcf86cd799439011', 'username': 'blaise'}
# ✅ AuthHandler works correctly
# /Users/blaiseforgwa/projects/learning-fastapi/.venv/lib/python3.13/site-packages/jwt/api_jwt.py:153: InsecureKeyLengthWarning: The HMAC key is 21 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# /Users/blaiseforgwa/projects/learning-fastapi/.venv/lib/python3.13/site-packages/jwt/api_jwt.py:371: InsecureKeyLengthWarning: The HMAC key is 21 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   decoded = self.decode_complete(
